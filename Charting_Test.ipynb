# %% [markdown]
# <a href="https://colab.research.google.com/github/ttaem/colab_notebook/blob/master/Charting_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Line Plots

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5,6,7,8,9]
y1 = [1,3,5,3,1,3,5,3,1]
y2 = [2,4,6,4,2,4,6,4,2]

plt.plot(x, y1, label='line L')
plt.plot(x, y2, label='line H')
#plt.plot()

plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Line Graph Example')

plt.legend()
plt.show()

# %% [markdown]
# ### Bar Plots

# %%
import matplotlib.pyplot as plt

x1 = [1,3,4,5,6,7,9]
y1 = [4,7,2,4,7,8,3]

x2 = [2,4,6,8,10]
y2 = [5,6,2,6,2]

plt.bar(x1, y1, label="Blue Bar", color='b')
plt.bar(x2, y2, label="Green Bar", color='g')

plt.xlabel("bar number")
plt.ylabel('bar height')
plt.title("Bar Chart Example")

plt.legend()
plt.show()

# %% [markdown]
# ###Histograms

# %%
import matplotlib.pyplot as plt
import numpy as np

n = np.random.randn(1000) + 5

m = range(len(n))
plt.bar(m, n)
plt.show()

plt.hist(n, bins=20)
plt.show()

plt.hist(n, cumulative=True, bins=20)
plt.show()
